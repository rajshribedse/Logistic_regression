# %% [markdown]
# <a href="https://colab.research.google.com/github/rajshribedse/Logistic_regression/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Disable Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")

# %%
data = pd.read_csv("/content/payment_fraud_2.csv")

# %%
data
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 0                  29         1   4.745402        paypal
# 1                 725         1   4.742303   storecredit
# 2                 845         1   4.921318    creditcard
# 3                 503         1   4.886641    creditcard
# 4                2000         1   5.040929    creditcard
# ...               ...       ...        ...           ...
# 39216             986         1   4.836982    creditcard
# 39217            1647         1   4.876771    creditcard
# 39218            1591         1   4.742303    creditcard
# 39219             237         1   4.921318    creditcard
# 39220             272         1   5.040929        paypal
#
#        paymentMethodAgeDays  label
# 0                 28.204861      0
# 1                  0.000000      0
# 2                  0.000000      0
# 3                  0.000000      0
# 4                  0.000000      0
# ...                     ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39221 entries, 0 to 39220
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   accountAgeDays        39221 non-null  int64
#  1   numItems              39221 non-null  int64
#  2   localTime             39221 non-null  float64
#  3   paymentMethod         39221 non-null  object
#  4   paymentMethodAgeDays  39221 non-null  float64
#  5   label                 39221 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.8+ MB

# %%
data.describe()
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    39221.000000  39221.000000  39221.000000          39221.000000
# mean       857.563984      1.084751      4.748232            122.641326
# std        804.788212      0.566899      0.389360            283.569177
# min          1.000000      1.000000      0.421214              0.000000
# 25%         72.000000      1.000000      4.742303              0.000000
# 50%        603.000000      1.000000      4.886641              0.012500
# 75%       1804.000000      1.000000      4.962055             87.510417
# max       2000.000000     29.000000      5.040929           1999.580556
#
#               label
# count  39221.000000
# mean       0.014278
# std        0.118636
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
data.isnull().sum()
# Out:
# accountAgeDays          0
# numItems                0
# localTime               0
# paymentMethod           0
# paymentMethodAgeDays    0
# label                   0
# dtype: int64

# %%
data.paymentMethod = data.paymentMethod.map({"paypal":"PayPal",
                                            "storecredit": "Store Credit", #A store credit is a document offered by a store to a customer who returns an item not eligible for a refund.
                                            "creditcard": "Credit Card"})

# %%
data.paymentMethod.unique()
# Out:
# array(['PayPal', 'Store Credit', 'Credit Card'], dtype=object)

# %%
payment_counts = data['paymentMethod'].value_counts()

# %%
# Create a pie chart
fig = px.pie(names=payment_counts.index, values=payment_counts.values, title='Payment Method Distribution')

# Show the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = np.array(data[["accountAgeDays", "numItems", "localTime", "paymentMethodAgeDays"]])
y = np.array(data[["label"]])

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,
                                               y,
                                               test_size = 0.2,
                                               random_state = 42)

# %%
logistic_model = LogisticRegression()
logistic_model.fit(xtrain, ytrain)
logistic_model.score(xtrain, ytrain)
# Out:
# 1.0

# %%
yhat = logistic_model.predict(xtest)

# %%
print(f"Accuracy Score of Logistic Regression Model: {accuracy_score(yhat, ytest)}")
# Out:
# Accuracy Score of Logistic Regression Model: 1.0

# %%
print(f"Confusion Matrix of Logistic Regression Model:\n {confusion_matrix(yhat, ytest)}")
# Out:
# Confusion Matrix of Logistic Regression Model:
#  [[7727    0]
#  [   0  118]]
